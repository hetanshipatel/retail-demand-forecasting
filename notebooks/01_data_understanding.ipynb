# %%
print("Retail Demand Forecasting")
print("Day 3 - Data Understanding")
# Out:
# Retail Demand Forecasting
# Day 3 - Data Understanding

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Projects/retail-demand-forecasting/data/raw/train.csv")

# %%
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
df.shape
# Out:
# (913000, 4)

# %%
df.columns
# Out:
# Index(['date', 'store', 'item', 'sales'], dtype='str')
